# %% [markdown]
# # HTML Parse Example
#
# Sources:
# * https://www.pluralsight.com/guides/extracting-data-html-beautifulsoup
# * https://www.geeksforgeeks.org/how-to-scrape-data-from-local-html-files-using-python/
# * https://beautiful-soup-4.readthedocs.io/en/latest/index.html?highlight=select_one
# * https://www.geeksforgeeks.org/how-to-parse-local-html-file-in-python/

# %%
#import the libraries
from bs4 import BeautifulSoup

# %%
# Opening the html file
HTMLFile = open("jabs/Patrick_Balke2017-01-12_16-49-33.html", "r")

# Reading the file
index = HTMLFile.read()

# Creating a BeautifulSoup object and specifying the parser
soup = BeautifulSoup(index, 'html.parser')

# %%
for message in soup.find_all('div'):
    print(message.text)
# Out:
# whoah jabber's crazy
#
#
#
# still no 100///
#
#
#
#
#
#
#
#
# i felt the same with the rams but i        really
# don't care about this move at all
# Mike cares
# or he would if he were still with us (rest in peace)
# I mostly sent that for the funny face the guy was making when I paused it
# because ESPN insists on autoplay videos in every article
# There's a reason they're the worldwide leader
#
#
#
#
#
#
#
#
# ah yes
# the undying love of chargers fans
# These are the kind of stories that lay bare the arbitrary nature of sports fandom
# you doing Sam Canas Slappy Hour?
# hopin so
# dope
# I got here at 7:30 today to figure out the thing I was telling you about from yesterday
# which was very unnecessary because the answer was really obvious
# #busepiphany
# #viewsfromthe6C
# hey same for me!
# niiiiice
# Chargers jacket will skyrocket in value now that no more San Diego merchandise will be made
# you got to start wearing that
# effective like now
# it's too relevant
# well work on getting the axes to hang under Kevin Love's floating head then
# haha
# i'm not sure i'm on board enough to spearhead that effort
#
#
#
#
#
#
#
#
# Look how funny that is!!!!
# hey man i won't get in your way!
# I call it the Jolly Kevin
# Like the jolly roger but with Kevin Love
# i don't get it
# the irony is that he doesn't look jolly at all
# haha
#
#
#
#
#
#
#
#
# still nothin
# Do I need to put a pirate hat on him?
# DOOOO YOU GET ITTT?!?!
# This a different roger than the one we worked with in case that's why you're confused
# that might be it
# but is the same kevin we work with?
#
#
#
#
#
#
#
#
# there ya go
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# HE GETS ME
# "In football terms, Zac had outkicked his coverage:"
# this is from the GQ article Drew links in the jamboroo
# haha
# it's about a guy who killed himself because of concussions
# and yet the dankness could not be kept at bay
#
#
#
#
# uggggh cmon drew
#
#
#
# people fucking love vin scully
# I have no idea who Vin Scully even is
# he's the dogers announcer
# he's the most famous announcer in baseball
# he retired this year
# he's got a cool voice and knows a lot of facts
# but people adore the shit out of him and i don't really get it
# he's the proto-typical announcer and doesn't pollute the game with mindless jabber, but while i think that's a great credit to him i think people go pretty over-board
# ah okay
# mannnnn
# I don't wanna do homework
# wha wha wha whattttttttt????????????????????????
# hahah
#
#
#
#
#
#
#
#
# this is insane
# haha
# probably the craziest thing in tennis is the before/after of djokovic's gluten intolerance
# before: massive choker, always fadings
# gluten is murder
# after: one of the greatest ever, excels almost entirely on grinding out long rallies and matches
# oh yeah i just stopped eating bread
# CRAZY
# my grandma lost a ton of weight (and she wasn't fat at all) when she got dentures and bread was too hard to chew or something
# How much bread was she eating???
# I think Nina remembers that I'm vegan and not gluten free now so that joke is retired
# though I eat very little gluten purely by accident
# / you can't mix it into bean dip

# %%
print(soup.get_text())
# Out:
# Chatbody{font-family: Segoe UI;font-size: 9pt; color: #4f5051;} .messageTable{width: 500px;} .buddyName{padding-top: 2.25pt; padding-right: 6pt; padding-bottom: 2.25pt; padding-left: 0pt; word-wrap: break-word; font-size: 10pt;} .timeStamp{white-space: nowrap; color: #858688; font-weight: normal; vertical-align: middle; padding-right: 6.75pt; padding-left: 6.75pt; font-size: 8pt; width: 60pt; text-align: right;} td.dateRollover{padding-top: 0pt; padding-right: 0pt; padding-bottom: 2.25pt; padding-left: 0pt; vertical-align: middle; white-space: nowrap; margin: 0pt; height: 10.5pt;} td.dateRollover > div{width: 100%; height: 100%; overflow: hidden; color: #858688; margin: 0px; padding: 0px;} .hiddenRow td{height: 0px; padding-top: 0px; padding-right: 0px; padding-bottom: 0px; padding-left: 0px;} .partyMsgText{color: #aeaeaf; font-style: italic; font-size: 10pt;} .progress-bg{position: relative; width: 100%; height: 1.5pt;} .progress-bg img{ display: block; float: left;} .pgr{right:0; position:absolute;} .FT, .FT-historical{ border: 1px solid #ebebec; border-radius: 1.5pt; margin-bottom: 3pt; margin-top: 3pt;} .FT .btn{ min-width: 45pt;} .FT-details{padding: 3.75pt 9pt 3pt 6pt; overflow: auto; min-height: 30pt;} .FT-actions{border-top: 1px solid #ebebec; padding: 3pt; clear: both; min-height: 24pt; overflow: auto;} .FT-stateicon{float: left; background-repeat:no-repeat; background-size: 100%; width: 8.25pt; height: 8.25pt; vertical-align: bottom; margin-top: 2.25pt;} .FT-fileicon{ float: left; margin-right:9pt; margin-top: 3pt; background-image: url("data:image/svg+xml;base64,..."); background-repeat:no-repeat; background-size: 100%; width: 18pt; height: 18pt;} .FT-tick{background-image: url("data:image/svg+xml;base64,...");} .FT-hyphen{height: 8.25pt; width: 4.5pt; background-image: url("data:image/svg+xml;base64,...");} .FT-upload{background-image: url("data:image/svg+xml;base64,...");} .FT-download{background-image: url("data:image/svg+xml;base64,...");} .FT-alert{background-image: url("data:image/svg+xml;base64,...");} .FT-white-alert{background-image: url("data:image/svg+xml;base64,..."); width: 12pt; height: 12pt; background-repeat: no-repeat; background-size: 100%;} td.FT-large-fileicon{ background-color: #f5a623; height:100%; border-bottom-left-radius: 2px; border-top-left-radius: 2px; vertical-align: central; width: 34.5pt;} td.FT-warning-text{ border-right: 1px solid #e5e5e5; border-top: 1px solid #e5e5e5; border-bottom: 1px solid #e5e5e5; border-bottom-right-radius:2px; border-top-right-radius: 2px; vertical-align: top; height: auto; width: auto;} .FT-warningdetails{padding: 5.25pt;} .FT-filedetails{float: left; width: 85% ; vertical-align: top; } .FT-filedetails .FT-filename{font size: 9pt; font-weight: normal; word-wrap: break-word;} .FT-warning-filesize{margin: 0; color: #999; font-size: 9pt; padding-right: 2.25pt;} .FT-filedetails p, .FT-filedetails .FT-filesize, .FT-warningdetails .FT-filesize{ margin: 0; color: #858688; font-size: 8pt; margin-right: 4.5pt;} .FT-filesize{ float: left; margin-right: 4.5pt;} .FT-feedback{ float: left; margin-left: 4.5pt; color: #858688; font-size: 8pt;} .FT-actions .FT-progress{ width:100%; clear: both; vertical-align: central; display: table; } .FT-actions .progress-bg-container{ width:100 %; vertical-align: central; padding: 8.25pt 4.5pt 8.25pt 0pt; display: table-cell;} .FT-actions .progress-bg{ height: 1.5pt; } .FT-actions .FT-progress .btn, .FT-actions .btn{ min-width: 45pt;} .FT-actions .FT-progress .btn{display: table-cell;} .FT-warning{ float: left; overflow: hidden; border-collapse:separate; border-spacing: 0px; width: 100%; border: 0;}
#
#
#
#
#
#
# Patrick Balkewhoah jabber's crazy10:55 AM
# Benjamin Schneedecker
#
#
#
#
#
#
#
#
#
#
# 10:55 AM
#
#
# Patrick Balke
#
#
#
#
#
# still no 100///
#
#
# 10:57 AM
#
#
# Benjamin Schneedecker
#
#
#
#
#
#
#
#
#
#
#
#
# 10:58 AM
#
#
# Patrick Balke
#
#
#
#
#
# i felt the same with the rams but i        really
# don't care about this move at all
#
#
# 10:58 AM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# Mike cares
#
#
# 10:59 AM
#
#
#
#
# or he would if he were still with us (rest in peace)
#
#
# 10:59 AM
#
#
#
#
# I mostly sent that for the funny face the guy was making when I paused it
#
#
# 10:59 AM
#
#
#
#
# because ESPN insists on autoplay videos in every article
#
#
# 10:59 AM
#
#
#
#
# There's a reason they're the worldwide leader
#
#
# 11:00 AM
#
#
# Patrick Balke
#
#
#
#
#
#
#
#
#
#
#
#
# 11:01 AM
#
#
#
#
# ah yes
#
#
# 11:01 AM
#
#
#
#
# the undying love of chargers fans
#
#
# 11:01 AM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# These are the kind of stories that lay bare the arbitrary nature of sports fandom
#
#
# 11:06 AM
#
#
#
#
# you doing Sam Canas Slappy Hour?
#
#
# 11:43 AM
#
#
# Patrick Balke
#
#
#
#
#
# hopin so
#
#
# 11:43 AM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# dope
#
#
# 11:44 AM
#
#
#
#
# I got here at 7:30 today to figure out the thing I was telling you about from yesterday
#
#
# 11:44 AM
#
#
#
#
# which was very unnecessary because the answer was really obvious
#
#
# 11:44 AM
#
#
#
#
# #busepiphany
#
#
# 11:44 AM
#
#
#
#
# #viewsfromthe6C
#
#
# 11:44 AM
#
#
# Patrick Balke
#
#
#
#
#
# hey same for me!
#
#
# 11:44 AM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# niiiiice
#
#
# 11:45 AM
#
#
#
#
# Chargers jacket will skyrocket in value now that no more San Diego merchandise will be made
#
#
# 1:55 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# you got to start wearing that
#
#
#
# 2:04 PM
#
#
#
#
#
# effective like now
#
#
#
# 2:04 PM
#
#
#
#
#
# it's too relevant
#
#
#
# 2:04 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# well work on getting the axes to hang under Kevin Love's floating head then
#
#
# 2:04 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# haha
#
#
#
# 2:05 PM
#
#
#
#
#
# i'm not sure i'm on board enough to spearhead that effort
#
#
#
# 2:05 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
#
#
#
#
#
#
#
# 2:09 PM
#
#
#
#
# Look how funny that is!!!!
#
#
# 2:09 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# hey man i won't get in your way!
#
#
#
# 2:10 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# I call it the Jolly Kevin
#
#
# 2:12 PM
#
#
#
#
# Like the jolly roger but with Kevin Love
#
#
# 2:12 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# i don't get it
#
#
#
# 2:12 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# the irony is that he doesn't look jolly at all
#
#
# 2:12 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# haha
#
#
#
# 2:12 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
#
#
#
#
#
#
#
# 2:12 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# still nothin
#
#
#
# 2:12 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# Do I need to put a pirate hat on him?
#
#
# 2:13 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# DOOOO YOU GET ITTT?!?!
#
#
#
# 2:13 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# This a different roger than the one we worked with in case that's why you're confused
#
#
# 2:13 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# that might be it
#
#
#
# 2:13 PM
#
#
#
#
#
# but is the same kevin we work with?
#
#
#
# 2:14 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
#
#
#
#
#
#
#
# 2:15 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# there ya go
#
#
#
# 2:15 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
#
#
#
#
#
#
#
# 2:16 PM
#
#
#
#
#
#
#
#
#
#
#
# 2:51 PM
#
#
#
#
# HE GETS ME
#
#
# 2:51 PM
#
#
#
#
# "In football terms, Zac had outkicked his coverage:"
#
#
# 3:56 PM
#
#
#
#
# this is from the GQ article Drew links in the jamboroo
#
#
# 3:56 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# haha
#
#
#
# 3:58 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# it's about a guy who killed himself because of concussions
#
#
# 3:58 PM
#
#
#
#
# and yet the dankness could not be kept at bay
#
#
# 3:58 PM
#
#
# Patrick Balke
#
#
#
#
#
#
#
#
#
#
# uggggh cmon drew
#
#
#
# 4:04 PM
#
#
#
#
#
# people fucking love vin scully
#
#
#
# 4:04 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# I have no idea who Vin Scully even is
#
#
# 4:04 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# he's the dogers announcer
#
#
#
# 4:04 PM
#
#
#
#
#
# he's the most famous announcer in baseball
#
#
#
# 4:04 PM
#
#
#
#
#
# he retired this year
#
#
#
# 4:04 PM
#
#
#
#
#
# he's got a cool voice and knows a lot of facts
#
#
#
# 4:05 PM
#
#
#
#
#
# but people adore the shit out of him and i don't really get it
#
#
#
# 4:05 PM
#
#
#
#
#
# he's the proto-typical announcer and doesn't pollute the game with mindless jabber, but while i think that's a great credit to him i think people go pretty over-board
#
#
#
# 4:06 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# ah okay
#
#
# 4:08 PM
#
#
#
#
# mannnnn
#
#
# 4:39 PM
#
#
#
#
# I don't wanna do homework
#
#
# 4:39 PM
#
#
#
#
# wha wha wha whattttttttt????????????????????????
#
#
# 4:39 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# hahah
#
#
#
# 4:41 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
#
#
#
#
#
#
#
# 4:44 PM
#
#
#
#
# this is insane
#
#
# 4:44 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# haha
#
#
#
# 4:44 PM
#
#
#
#
#
# probably the craziest thing in tennis is the before/after of djokovic's gluten intolerance
#
#
#
# 4:44 PM
#
#
#
#
#
# before: massive choker, always fadings
#
#
#
# 4:45 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# gluten is murder
#
#
# 4:45 PM
#
#
# Patrick Balke
#
#
#
#
#
#
# after: one of the greatest ever, excels almost entirely on grinding out long rallies and matches
#
#
#
# 4:45 PM
#
#
#
#
#
# oh yeah i just stopped eating bread
#
#
#
# 4:45 PM
#
#
#
#
#
# CRAZY
#
#
#
# 4:45 PM
#
#
# Benjamin Schneedecker
#
#
#
#
#
# my grandma lost a ton of weight (and she wasn't fat at all) when she got dentures and bread was too hard to chew or something
#
#
# 4:46 PM
#
#
#
#
# How much bread was she eating???
#
#
# 4:46 PM
#
#
#
#
# I think Nina remembers that I'm vegan and not gluten free now so that joke is retired
#
#
# 4:46 PM
#
#
#
#
# though I eat very little gluten purely by accident
#
#
# 4:47 PM
#
#
#
#
# / you can't mix it into bean dip
#
#
# 4:47 PM
